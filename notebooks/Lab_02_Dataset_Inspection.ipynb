# %%
# !git clone https://github.com/Aishwarya-93/Deepfake-Detection-KYC
# Out:
# fatal: destination path 'Deepfake-Detection-KYC' already exists and is not an empty directory.

# %%
# %cd Deepfake-Detection-KYC
# Out:
# /content/Deepfake-Detection-KYC

# %%
# !pip install -q kaggle

# %%
# !kaggle datasets list | head
# Out:
# ...
# ref                                                             title                                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  --------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# rauffauzanrambe/fifa-world-cup-2026-player-performance-dataset  FIFA World Cup 2026 Player Performance Dataset         4154062  2026-06-10 12:58:47.093000          10536        251                1
# ashyou09/apple-products-pricing-dataset-2020-2026               Apple Products Pricing Dataset (2020-2026)🍎            1569012  2026-07-04 16:06:56.590000           1440         28                1
# arjunmehta1992/chocolate-sales-in-20222023                      Chocolate Sales in 2022–2023                           4820417  2026-06-21 03:52:16.600000           3620         48                1
# ...

# %%
# !kaggle datasets download -d xdxd003/ff-c23
# Out:
# Dataset URL: https://www.kaggle.com/datasets/xdxd003/ff-c23
# License(s): other
# ...
# 100% 16.7G/16.7G [01:59<00:00, 150MB/s]

# %%
# !ls -lh
# Out:
# total 17G
# drwxr-xr-x 6 root root 4.0K Jul 10 13:45 data
# drwxr-xr-x 2 root root 4.0K Jul 10 13:45 docs
# -rw-r--r-- 1 root root  206 Jul 10 13:45 environment.yml
# -rw-r--r-- 1 root root  17G Dec  7  2024 ff-c23.zip
# drwxr-xr-x 6 root root 4.0K Jul 10 13:45 outputs
# drwxr-xr-x 2 root root 4.0K Jul 10 13:45 presentations
# -rw-r--r-- 1 root root  960 Jul 10 13:45 README.md
# drwxr-xr-x 2 root root 4.0K Jul 10 13:45 reports
# -rw-r--r-- 1 root root    0 Jul 10 13:45 requirements.txt
# drwxr-xr-x 8 root root 4.0K Jul 10 13:45 src

# %%
# !pip install -U kaggle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.5/111.5 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.8/243.8 kB 9.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: kagglesdk
#     Found existing installation: kagglesdk 0.1.23
#     Uninstalling kagglesdk-0.1.23:
#       Successfully uninstalled kagglesdk-0.1.23
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 2.0.2
#     Uninstalling kaggle-2.0.2:
#       Successfully uninstalled kaggle-2.0.2
# ...

# %%
# !kaggle --version
# Out:
# Kaggle CLI 2.2.3

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   54G   55G  50% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G     0  5.7G   0% /dev/shm
# /dev/root       2.0G  1.3G  696M  65% /usr/sbin/docker-init
# tmpfs           6.4G  160K  6.4G   1% /var/colab
# /dev/sda1       114G   55G   60G  48% /kaggle/input
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %%
# !unzip -q ff-c23.zip -d data/raw/
# Out:
# checkdir:  cannot create extraction directory: data/raw
#            No such file or directory

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# Deepfake-Detection-KYC	ff-c23.zip  sample_data

# %%
# %cd /content/Deepfake-Detection-KYC
# Out:
# /content/Deepfake-Detection-KYC

# %%
# !pwd
# Out:
# /content/Deepfake-Detection-KYC

# %%
# !ls
# Out:
# data  environment.yml  outputs	      README.md  requirements.txt
# docs  ff-c23.zip       presentations  reports	 src

# %%
# !mkdir -p data/raw
# !mkdir -p data/processed
# !mkdir -p data/metadata

# %%
# !find data -maxdepth 2 -type d
# Out:
# data
# data/processed
# data/raw
# data/sample
# data/metadata

# %%
# !unzip -q /content/ff-c23.zip -d data/raw

# %%
# !find data/raw -maxdepth 2 -type d
# Out:
# data/raw
# data/raw/FaceForensics++_C23
# data/raw/FaceForensics++_C23/FaceSwap
# data/raw/FaceForensics++_C23/DeepFakeDetection
# data/raw/FaceForensics++_C23/csv
# data/raw/FaceForensics++_C23/Face2Face
# data/raw/FaceForensics++_C23/FaceShifter
# data/raw/FaceForensics++_C23/NeuralTextures
# data/raw/FaceForensics++_C23/original
# data/raw/FaceForensics++_C23/Deepfakes

# %%
from pathlib import Path

# ----------------------------
# Dataset Path
# ----------------------------

DATASET_PATH = Path("data/raw/FaceForensics++_C23")

# ----------------------------
# Check Dataset
# ----------------------------

if not DATASET_PATH.exists():
    print("Dataset not found!")
    exit()

print("=" * 60)
print("FaceForensics++ Dataset Inspection")
print("=" * 60)

print("\nDataset Location:")
print(DATASET_PATH)

print("\nFolders Found:\n")

folders = []

for folder in sorted(DATASET_PATH.iterdir()):

    if folder.is_dir():
      if folder.name != "csv":

        folders.append(folder.name)

        print(f"• {folder.name}")

print("\nTotal folders:", len(folders))
# Out:
# ...
# FaceForensics++ Dataset Inspection
# ...
#
# Dataset Location:
# data/raw/FaceForensics++_C23
#
# Folders Found:
#
# • DeepFakeDetection
# • Deepfakes
# • Face2Face
# • FaceShifter
# • FaceSwap
# • NeuralTextures
# • original
#
# Total folders: 7

# %%
import os

csv_folder = "data/raw/FaceForensics++_C23/csv"

print("CSV Files:\n")

for file in sorted(os.listdir(csv_folder)):
    print(file)
# Out:
# CSV Files:
#
# DeepFakeDetection.csv
# Deepfakes.csv
# FF++_Metadata.csv
# FF++_Metadata_Shuffled.csv
# Face2Face.csv
# FaceShifter.csv
# FaceSwap.csv
# Mean_Data.csv
# NeuralTextures.csv
# original.csv

# %%
import pandas as pd

df = pd.read_csv(
    "data/raw/FaceForensics++_C23/csv/original.csv"
)

df.head()
# Out:
#    Unnamed: 0         File Path Label  Frame Count  Width  Height Codec  \
# 0           0  original/000.mp4  REAL          396    640     480  h264
# 1           1  original/001.mp4  REAL          460   1280     720  h264
# 2           2  original/002.mp4  REAL          693   1280     720  h264
# 3           3  original/003.mp4  REAL          303    640     480  h264
# 4           4  original/004.mp4  REAL          309   1280     720  h264
#
#    File Size(MB)
# 0           0.85
# 1           2.78
# 2           2.02
# 3           0.58
# 4           1.20

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'File Path', 'Label', 'Frame Count', 'Width', 'Height',
#        'Codec', 'File Size(MB)'],
#       dtype='object')

# %%
df.sample(5)
# Out:
#      Unnamed: 0         File Path Label  Frame Count  Width  Height Codec  \
# 357         357  original/357.mp4  REAL          346    854     480  h264
# 443         443  original/443.mp4  REAL         1146    640     480  h264
# 272         272  original/272.mp4  REAL          323   1280     720  h264
# 909         909  original/909.mp4  REAL          637    640     480  h264
# 595         595  original/595.mp4  REAL          565   1280     720  h264
#
#      File Size(MB)
# 357           0.51
# 443           1.60
# 272           1.50
# 909           0.58
# 595           2.06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1000 non-null   int64
#  1   File Path      1000 non-null   object
#  2   Label          1000 non-null   object
#  3   Frame Count    1000 non-null   int64
#  4   Width          1000 non-null   int64
#  5   Height         1000 non-null   int64
#  6   Codec          1000 non-null   object
#  7   File Size(MB)  1000 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 62.6+ KB
